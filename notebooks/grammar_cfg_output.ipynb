# %%
# %autoreload 2

# %%
from argparse import Namespace
from collections import defaultdict
import dataclasses
import copy
import gzip
import os
import pickle
import sys
import time
import typing
import re

from IPython.display import display, Markdown, Latex
import numpy as np
import tqdm.notebook as tqdm

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../src'))
from src.ast_utils import load_games_from_file, _extract_game_id
from ast_counter_sampler import *

# %%
RANDOM_SEED = 33

args = Namespace(
    parse_counter=False, 
    counter_output_path=os.path.join('..', DEFAULT_COUNTER_OUTPUT_PATH),
    grammar_file=os.path.join('..', DEFAULT_GRAMMAR_FILE),
    random_seed=RANDOM_SEED,
    test_files=['../dsl/interactive-beta.pddl'],
    dont_tqdm=False,
)

grammar = open(args.grammar_file).read()
grammar_parser = tatsu.compile(grammar)
counter = parse_or_load_counter(args, grammar_parser)
sampler = ASTSampler(grammar_parser, counter, seed=args.random_seed)

PATTERN_RULES = {k: re.compile(v['pattern']) for k, v in sampler.rules.items() if 'pattern' in v}
PATTERN_RULES['predicate_name'] = PATTERN_RULES['name']
PATTERN_RULES['type_name'] = PATTERN_RULES['name']
# Out:
# No counted data for function_distance_side_4.arg_1
# No counted data for function_distance_side_4.arg_2
# No counted data for function_distance_side_4.arg_3
# No counted data for function_distance_side_4.arg_4
# No counted data for setup_not.not_args
# String token rule for any: {'token_posterior': {'(any)': 1}, 'production': [('token', '(any)')]}
# No counted data for hold_for.hold_pred
# No counted data for hold_to_end.hold_pred
# No counted data for forall_seq.forall_seq_vars
# No counted data for forall_seq.forall_seq_then
# No counted data for terminal_not.not_args
# No counted data for scoring_external_minimize.scoring_expr
# No counted data for scoring_and.and_args
# No counted data for scoring_or.or_args
# No counted data for scoring_not.not_args
# String token rule for total_time: {'token_posterior': {'(total-time)': 1}, 'production': [('token', '(total-time)')]}
# String token rule for total_score: {'token_posterior': {'(total-score)': 1}, 'production': [('token', '(total-score)')]}
# No counted data for scoring_equals_comp.expr
# No counted data for count_longest.name_and_types
# No counted data for count_shortest.name_and_types
# No counted data for count_total.name_and_types
# No counted data for count_increasing_measure.name_and_types

# %%
@dataclasses.dataclass
class Expansion:
    rule: str
    expansions: typing.List[str] = dataclasses.field(default_factory=list)
    probability: float = 1.0

    def __str__(self):
        return f'{self.rule.upper()} &rarr; {" ".join(self.expansions)}    (P = {self.probability:.4f})'


def _add_to_expansions(expansions: typing.List[Expansion], addition: str, probability=None):
    for expansion in expansions:
        expansion.expansions.append(addition)

        if probability is not None:
            expansion.probability *= probability
    
    return expansions


def _multiple_add_to_components(expansions: typing.List[Expansion], additions_to_probabilities: typing.Dict[str, float]):
    if len(additions_to_probabilities) == 1:
        key = next(iter(additions_to_probabilities))
        return _add_to_expansions(expansions, key.upper(), additions_to_probabilities[key])

    original_length = len(expansions)
    temp = [copy.deepcopy(expansions) for _ in range(len(additions_to_probabilities))]
    expansions = [comp for component in temp for comp in component]

    for i, (addition, probability) in enumerate(additions_to_probabilities.items()):
        for j in range(original_length):
            current = expansions[i * original_length + j]
            current.expansions.append(addition.upper())
            if probability is not None:
                current.probability *= probability

    return expansions


def print_rule_cfg(rule: str, rules: typing.Dict[str, typing.Dict[str, typing.Any]],
    pattern_rules: typing.Dict[str, re.Pattern] = PATTERN_RULES):

    if rule not in rules:
        return [], [], {}

    rule_dict = rules[rule]

    if PRODUCTION not in rule_dict:
        raise ValueError(f'No production for {rule}')

    expansions = [Expansion(rule)]
    encountered_rules = []
    encountered_tokens = defaultdict(dict)

    for prod_type, prod_value in rule_dict[PRODUCTION]:
        if prod_type == RULE:
            expansions = _add_to_expansions(expansions, prod_value.upper())
            encountered_rules.append(prod_value)

        elif prod_type == TOKEN:
            if prod_value == SAMPLE:
                expansions = _multiple_add_to_components(expansions, rule_dict[TOKEN_POSTERIOR])

            elif prod_value != EOF:
                expansions = _add_to_expansions(expansions, prod_value)

        elif prod_type == NAMED:
            if prod_value not in rule_dict:
                raise ValueError(f'Unknown named {prod_value}')

            named_dict = rule_dict[prod_value]
            options = named_dict[OPTIONS]
            
            if isinstance(options, str):
                out = options.upper()
                if MIN_LENGTH in named_dict:
                    min_length = named_dict[MIN_LENGTH]
                    out = f'[ {out} ]{"*" if min_length == 0 else "+"}'

                expansions = _add_to_expansions(expansions, out)
                encountered_rules.append(options)
                options = [options]

            else:
                if MIN_LENGTH in named_dict:
                    raise ValueError(f'Min length not supported for multiple options {prod_value}')
                expansions = _multiple_add_to_components(expansions, 
                    {opt: (named_dict[RULE_POSTERIOR][opt] if (RULE_POSTERIOR in named_dict and opt in named_dict[RULE_POSTERIOR]) else None) 
                    for opt in options}  # type: ignore
                )
                encountered_rules.extend(options)

            if TOKEN_POSTERIOR in named_dict:
                for t, p in named_dict[TOKEN_POSTERIOR].items():
                    if t in rules: continue

                    if len(options) == 1:
                        encountered_tokens[options[0]][t] = p
                        continue

                    if isinstance(t, (int, float)):
                        encountered_tokens['number'][t] = p
                        continue

                    for opt in options:
                        if opt in pattern_rules and pattern_rules[opt].match(t):
                            encountered_tokens[opt][t] = p
                            break

        elif prod_type == PATTERN:
            expansions = _add_to_expansions(expansions, f'/{prod_value}/')

        else:
            raise ValueError(f'Unknown production type {prod_type}')

    sum_probs = sum(exp.probability for exp in expansions)
    for exp in expansions:
        exp.probability /= sum_probs

    return [str(exp) for exp in expansions], encountered_rules, encountered_tokens


def print_rules_cfg(rules: typing.Dict[str, typing.Dict[str, typing.Any]], start_rule: str = START):
    rule_frontier = [start_rule]
    encountered_rules = set(rule_frontier)
    
    cfg_rules = ['## CFG-like grammar printout']
    token_rule_expansions = defaultdict(dict)

    while rule_frontier:
        rule = rule_frontier.pop()
        cfgs, new_rules, new_tokens = print_rule_cfg(rule, rules)
        cfg_rules.extend(cfgs)

        for new_rule in reversed(new_rules):
            if new_rule not in encountered_rules:
                rule_frontier.append(new_rule)
                encountered_rules.add(new_rule)

        for rule, tokens in new_tokens.items():
            token_rule_expansions[rule].update(tokens)

    cfg_rules.append('## Token rule expansions')
    for rule, tokens in token_rule_expansions.items():
        for token, prob in tokens.items():
            cfg_rules.append(f'{rule.upper()} &rarr; {token}    (P = {prob:.4f})')

    return '\n\n'.join(cfg_rules)

markdown_output = print_rules_cfg(sampler.rules)

# %%
print(markdown_output)
# Out:
# ## CFG-like grammar printout
#
# START &rarr; (define GAME_DEF DOMAIN_DEF SETUP_DEF CONSTRAINTS_DEF TERMINAL_DEF SCORING_DEF )    (P = 1.0000)
#
# GAME_DEF &rarr; (game ID )    (P = 1.0000)
#
# ID &rarr; /[a-z0-9][a-z0-9\-]+/    (P = 1.0000)
#
# DOMAIN_DEF &rarr; (:domain ID )    (P = 1.0000)
#
# SETUP_DEF &rarr; (:setup SETUP )    (P = 1.0000)
#
# SETUP &rarr; SETUP_AND    (P = 0.2464)
#
# SETUP &rarr; SETUP_OR    (P = 0.0214)
#
# SETUP &rarr; SETUP_NOT    (P = 0.0179)
#
# SETUP &rarr; SETUP_EXISTS    (P = 0.2107)
#
# SETUP &rarr; SETUP_FORALL    (P = 0.1357)
#
# SETUP &rarr; SETUP_STATEMENT    (P = 0.3679)
#
# SETUP_AND &rarr; (and [ SETUP ]+ )    (P = 1.0000)
#
# SETUP_OR &rarr; (or [ SETUP ]+ )    (P = 1.0000)
#
# SETUP_NOT &rarr; (not SETUP )    (P = 1.0000)
#
# SETUP_EXISTS &rarr; (exists VARIABLE_LIST SETUP )    (P = 1.0000)
#
# VARIABLE_LIST &rarr; ( [ VARIABLE_TYPE_DEF ]+ )    (P = 1.0000)
#
# VARIABLE_TYPE_DEF &rarr; [ VARIABLE ]+ - TYPE_DEFINITION    (P = 1.0000)
#
# VARIABLE &rarr; /\?[a-z][a-z0-9]*/    (P = 1.0000)
#
# TYPE_DEFINITION &rarr; TYPE_NAME    (P = 0.5000)
#
# TYPE_DEFINITION &rarr; EITHER_TYPES    (P = 0.5000)
#
# TYPE_NAME &rarr; NAME    (P = 1.0000)
#
# NAME &rarr; /[A-Za-z][A-Za-z0-9_]*/    (P = 1.0000)
#
# EITHER_TYPES &rarr; (either [ TYPE_NAME ]+ )    (P = 1.0000)
#
# SETUP_FORALL &rarr; (forall VARIABLE_LIST SETUP )    (P = 1.0000)
#
# SETUP_STATEMENT &rarr; SETUP_GAME_CONSERVED    (P = 0.6389)
#
# SETUP_STATEMENT &rarr; SETUP_GAME_OPTIONAL    (P = 0.3611)
#
# SETUP_GAME_CONSERVED &rarr; (game-conserved SUPER_PREDICATE )    (P = 1.0000)
#
# SUPER_PREDICATE &rarr; SUPER_PREDICATE_AND    (P = 0.1947)
#
# SUPER_PREDICATE &rarr; SUPER_PREDICATE_OR    (P = 0.0160)
#
# SUPER_PREDICATE &rarr; SUPER_PREDICATE_NOT    (P = 0.1800)
#
# SUPER_PREDICATE &rarr; SUPER_PREDICATE_EXISTS    (P = 0.0236)
#
# SUPER_PREDICATE &rarr; SUPER_PREDICATE_FORALL    (P = 0.0067)
#
# SUPER_PREDICATE &rarr; FUNCTION_COMPARISON    (P = 0.0467)
#
# SUPER_PREDICATE &rarr; PREDICATE    (P = 0.5324)
#
# SUPER_PREDICATE_AND &rarr; (and [ SUPER_PREDICATE ]+ )    (P = 1.0000)
#
# SUPER_PREDICATE_OR &rarr; (or [ SUPER_PREDICATE ]+ )    (P = 1.0000)
#
# SUPER_PREDICATE_NOT &rarr; (not SUPER_PREDICATE )    (P = 1.0000)
#
# SUPER_PREDICATE_EXISTS &rarr; (exists VARIABLE_LIST SUPER_PREDICATE )    (P = 1.0000)
#
# SUPER_PREDICATE_FORALL &rarr; (forall VARIABLE_LIST SUPER_PREDICATE )    (P = 1.0000)
#
# FUNCTION_COMPARISON &rarr; TWO_ARG_COMPARISON    (P = 0.9364)
#
# FUNCTION_COMPARISON &rarr; MULTIPLE_ARGS_EQUAL_COMPARISON    (P = 0.0636)
#
# TWO_ARG_COMPARISON &rarr; ( BINARY_COMP COMPARISON_ARG COMPARISON_ARG )    (P = 1.0000)
#
# BINARY_COMP &rarr; <=    (P = 0.2000)
#
# BINARY_COMP &rarr; <    (P = 0.2000)
#
# BINARY_COMP &rarr; =    (P = 0.2000)
#
# BINARY_COMP &rarr; >=    (P = 0.2000)
#
# BINARY_COMP &rarr; >    (P = 0.2000)
#
# COMPARISON_ARG &rarr; FUNCTION_EVAL    (P = 0.5000)
#
# COMPARISON_ARG &rarr; NUMBER    (P = 0.5000)
#
# FUNCTION_EVAL &rarr; FUNCTION_BUILDING_SIZE    (P = 0.0467)
#
# FUNCTION_EVAL &rarr; FUNCTION_DISTANCE    (P = 0.7933)
#
# FUNCTION_EVAL &rarr; FUNCTION_DISTANCE_SIDE_3    (P = 0.0667)
#
# FUNCTION_EVAL &rarr; FUNCTION_DISTANCE_SIDE_4    (P = 0.0333)
#
# FUNCTION_EVAL &rarr; FUNCTION_X_POSITION    (P = 0.0600)
#
# FUNCTION_BUILDING_SIZE &rarr; (building_size PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_OR_FUNCTION_TERM &rarr; TYPE_NAME    (P = 0.5000)
#
# PREDICATE_OR_FUNCTION_TERM &rarr; VARIABLE    (P = 0.5000)
#
# FUNCTION_DISTANCE &rarr; (distance PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# FUNCTION_DISTANCE_SIDE_3 &rarr; (distance_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# FUNCTION_DISTANCE_SIDE_4 &rarr; (distance_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# FUNCTION_X_POSITION &rarr; (x_position PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# NUMBER &rarr; /\d*\.?\d+/    (P = 1.0000)
#
# MULTIPLE_ARGS_EQUAL_COMPARISON &rarr; (= [ COMPARISON_ARG ]+ )    (P = 1.0000)
#
# PREDICATE &rarr; PREDICATE_ABOVE    (P = 0.0076)
#
# PREDICATE &rarr; PREDICATE_ADJACENT    (P = 0.0612)
#
# PREDICATE &rarr; PREDICATE_ADJACENT_SIDE_3    (P = 0.0128)
#
# PREDICATE &rarr; PREDICATE_ADJACENT_SIDE_4    (P = 0.0053)
#
# PREDICATE &rarr; PREDICATE_AGENT_CROUCHES    (P = 0.0053)
#
# PREDICATE &rarr; PREDICATE_AGENT_HOLDS    (P = 0.2509)
#
# PREDICATE &rarr; PREDICATE_BETWEEN    (P = 0.0091)
#
# PREDICATE &rarr; PREDICATE_BROKEN    (P = 0.0053)
#
# PREDICATE &rarr; PREDICATE_EQUAL_X_POSITION    (P = 0.0053)
#
# PREDICATE &rarr; PREDICATE_EQUAL_Z_POSITION    (P = 0.0076)
#
# PREDICATE &rarr; PREDICATE_FACES    (P = 0.0083)
#
# PREDICATE &rarr; PREDICATE_GAME_OVER    (P = 0.0068)
#
# PREDICATE &rarr; PREDICATE_GAME_START    (P = 0.0060)
#
# PREDICATE &rarr; PREDICATE_IN    (P = 0.0960)
#
# PREDICATE &rarr; PREDICATE_IN_MOTION    (P = 0.2389)
#
# PREDICATE &rarr; PREDICATE_IS_SETUP_OBJECT    (P = 0.0113)
#
# PREDICATE &rarr; PREDICATE_OBJECT_ORIENTATION    (P = 0.0151)
#
# PREDICATE &rarr; PREDICATE_ON    (P = 0.1300)
#
# PREDICATE &rarr; PREDICATE_OPEN    (P = 0.0060)
#
# PREDICATE &rarr; PREDICATE_OPPOSITE    (P = 0.0068)
#
# PREDICATE &rarr; PREDICATE_RUG_COLOR_UNDER    (P = 0.0121)
#
# PREDICATE &rarr; PREDICATE_SAME_COLOR    (P = 0.0212)
#
# PREDICATE &rarr; PREDICATE_SAME_OBJECT    (P = 0.0091)
#
# PREDICATE &rarr; PREDICATE_SAME_TYPE    (P = 0.0144)
#
# PREDICATE &rarr; PREDICATE_TOGGLED_ON    (P = 0.0068)
#
# PREDICATE &rarr; PREDICATE_TOUCH    (P = 0.0408)
#
# PREDICATE_ABOVE &rarr; (above PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_ADJACENT &rarr; (adjacent PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_ADJACENT_SIDE_3 &rarr; (adjacent_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_ADJACENT_SIDE_4 &rarr; (adjacent_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_AGENT_CROUCHES &rarr; (agent_crouches  )    (P = 1.0000)
#
# PREDICATE_AGENT_HOLDS &rarr; (agent_holds PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_BETWEEN &rarr; (between PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_BROKEN &rarr; (broken PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_EQUAL_X_POSITION &rarr; (equal_x_position PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_EQUAL_Z_POSITION &rarr; (equal_z_position PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_FACES &rarr; (faces PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_GAME_OVER &rarr; (game_over  )    (P = 1.0000)
#
# PREDICATE_GAME_START &rarr; (game_start  )    (P = 1.0000)
#
# PREDICATE_IN &rarr; (in PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_IN_MOTION &rarr; (in_motion PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_IS_SETUP_OBJECT &rarr; (is_setup_object PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_OBJECT_ORIENTATION &rarr; (object_orientation PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_ON &rarr; (on PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_OPEN &rarr; (open PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_OPPOSITE &rarr; (opposite PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_RUG_COLOR_UNDER &rarr; (rug_color_under PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_SAME_COLOR &rarr; (same_color PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_SAME_OBJECT &rarr; (same_object PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_SAME_TYPE &rarr; (same_type PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_TOGGLED_ON &rarr; (toggled_on PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# PREDICATE_TOUCH &rarr; (touch PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
#
# SETUP_GAME_OPTIONAL &rarr; (game-optional SUPER_PREDICATE )    (P = 1.0000)
#
# CONSTRAINTS_DEF &rarr; (:constraints PREFERENCES )    (P = 1.0000)
#
# PREFERENCES &rarr; (and [ PREF_DEF ]+ )    (P = 1.0000)
#
# PREF_DEF &rarr; PREFERENCE    (P = 0.7189)
#
# PREF_DEF &rarr; PREF_FORALL    (P = 0.2811)
#
# PREFERENCE &rarr; (preference PREFERENCE_NAME PREF_BODY )    (P = 1.0000)
#
# PREFERENCE_NAME &rarr; NAME    (P = 1.0000)
#
# PREF_BODY &rarr; PREF_BODY_EXISTS    (P = 0.8976)
#
# PREF_BODY &rarr; THEN    (P = 0.0780)
#
# PREF_BODY &rarr; AT_END    (P = 0.0244)
#
# PREF_BODY_EXISTS &rarr; (exists VARIABLE_LIST THEN )    (P = 0.8042)
#
# PREF_BODY_EXISTS &rarr; (exists VARIABLE_LIST AT_END )    (P = 0.1958)
#
# THEN &rarr; (then [ SEQ_FUNC ]+ )    (P = 1.0000)
#
# SEQ_FUNC &rarr; ANY    (P = 0.0095)
#
# SEQ_FUNC &rarr; ONCE    (P = 0.6015)
#
# SEQ_FUNC &rarr; ONCE_MEASURE    (P = 0.0114)
#
# SEQ_FUNC &rarr; HOLD    (P = 0.2770)
#
# SEQ_FUNC &rarr; WHILE_HOLD    (P = 0.0721)
#
# SEQ_FUNC &rarr; HOLD_FOR    (P = 0.0095)
#
# SEQ_FUNC &rarr; HOLD_TO_END    (P = 0.0095)
#
# SEQ_FUNC &rarr; FORALL_SEQ    (P = 0.0095)
#
# ANY &rarr; (any)    (P = 1.0000)
#
# ONCE &rarr; (once  SUPER_PREDICATE )    (P = 1.0000)
#
# ONCE_MEASURE &rarr; (once-measure SUPER_PREDICATE FUNCTION_EVAL )    (P = 1.0000)
#
# HOLD &rarr; (hold SUPER_PREDICATE )    (P = 1.0000)
#
# WHILE_HOLD &rarr; (hold-while SUPER_PREDICATE [ SUPER_PREDICATE ]+ )    (P = 1.0000)
#
# HOLD_FOR &rarr; (hold-for NUMBER SUPER_PREDICATE )    (P = 1.0000)
#
# HOLD_TO_END &rarr; (hold-to-end SUPER_PREDICATE )    (P = 1.0000)
#
# FORALL_SEQ &rarr; (forall-sequence VARIABLE_LIST THEN )    (P = 1.0000)
#
# AT_END &rarr; (at-end SUPER_PREDICATE )    (P = 1.0000)
#
# PREF_FORALL &rarr; (forall VARIABLE_LIST PREF_FORALL_PREFS )    (P = 1.0000)
#
# PREF_FORALL_PREFS &rarr; (and [ PREFERENCE ]+ )    (P = 1.0000)
#
# TERMINAL_DEF &rarr; (:terminal TERMINAL )    (P = 1.0000)
#
# TERMINAL &rarr; TERMINAL_AND    (P = 0.0606)
#
# TERMINAL &rarr; TERMINAL_OR    (P = 0.1919)
#
# TERMINAL &rarr; TERMINAL_NOT    (P = 0.0505)
#
# TERMINAL &rarr; TERMINAL_COMP    (P = 0.6970)
#
# TERMINAL_AND &rarr; (and [ TERMINAL ]+ )    (P = 1.0000)
#
# TERMINAL_OR &rarr; (or [ TERMINAL ]+ )    (P = 1.0000)
#
# TERMINAL_NOT &rarr; (not TERMINAL )    (P = 1.0000)
#
# TERMINAL_COMP &rarr; ( BINARY_COMP TERMINAL_EXPR TERMINAL_EXPR )    (P = 1.0000)
#
# TERMINAL_EXPR &rarr; SCORING_EXPR    (P = 1.0000)
#
# SCORING_EXPR &rarr; SCORING_EXTERNAL_MAXIMIZE    (P = 0.0073)
#
# SCORING_EXPR &rarr; SCORING_EXTERNAL_MINIMIZE    (P = 0.0020)
#
# SCORING_EXPR &rarr; SCORING_MULTI_EXPR    (P = 0.0859)
#
# SCORING_EXPR &rarr; SCORING_BINARY_EXPR    (P = 0.0028)
#
# SCORING_EXPR &rarr; SCORING_NEG_EXPR    (P = 0.0109)
#
# SCORING_EXPR &rarr; SCORING_AND    (P = 0.0020)
#
# SCORING_EXPR &rarr; SCORING_OR    (P = 0.0020)
#
# SCORING_EXPR &rarr; SCORING_NOT    (P = 0.0020)
#
# SCORING_EXPR &rarr; TOTAL_TIME    (P = 0.2500)
#
# SCORING_EXPR &rarr; TOTAL_SCORE    (P = 0.2500)
#
# SCORING_EXPR &rarr; NUMBER    (P = 0.2500)
#
# SCORING_EXPR &rarr; PREFERENCE_EVAL    (P = 0.1272)
#
# SCORING_EXPR &rarr; SCORING_COMPARISON    (P = 0.0077)
#
# SCORING_EXTERNAL_MAXIMIZE &rarr; (external-forall-maximize SCORING_EXPR )    (P = 1.0000)
#
# SCORING_EXTERNAL_MINIMIZE &rarr; (external-forall-minimize SCORING_EXPR )    (P = 1.0000)
#
# SCORING_MULTI_EXPR &rarr; ( MULTI_OP [ SCORING_EXPR ]+ )    (P = 1.0000)
#
# MULTI_OP &rarr; +    (P = 0.5000)
#
# MULTI_OP &rarr; *    (P = 0.5000)
#
# SCORING_BINARY_EXPR &rarr; ( BINARY_OP SCORING_EXPR SCORING_EXPR )    (P = 1.0000)
#
# BINARY_OP &rarr; -    (P = 0.5000)
#
# BINARY_OP &rarr; /    (P = 0.5000)
#
# SCORING_NEG_EXPR &rarr; (- SCORING_EXPR )    (P = 1.0000)
#
# SCORING_AND &rarr; (and [ SCORING_EXPR ]+ )    (P = 1.0000)
#
# SCORING_OR &rarr; (or [ SCORING_EXPR ]+ )    (P = 1.0000)
#
# SCORING_NOT &rarr; (not SCORING_EXPR )    (P = 1.0000)
#
# TOTAL_TIME &rarr; (total-time)    (P = 1.0000)
#
# TOTAL_SCORE &rarr; (total-score)    (P = 1.0000)
#
# PREFERENCE_EVAL &rarr; COUNT    (P = 0.5095)
#
# PREFERENCE_EVAL &rarr; COUNT_OVERLAPPING    (P = 0.0217)
#
# PREFERENCE_EVAL &rarr; COUNT_ONCE    (P = 0.0786)
#
# PREFERENCE_EVAL &rarr; COUNT_ONCE_PER_OBJECTS    (P = 0.2493)
#
# PREFERENCE_EVAL &rarr; COUNT_LONGEST    (P = 0.0136)
#
# PREFERENCE_EVAL &rarr; COUNT_SHORTEST    (P = 0.0136)
#
# PREFERENCE_EVAL &rarr; COUNT_TOTAL    (P = 0.0136)
#
# PREFERENCE_EVAL &rarr; COUNT_INCREASING_MEASURE    (P = 0.0136)
#
# PREFERENCE_EVAL &rarr; COUNT_UNIQUE_POSITIONS    (P = 0.0163)
#
# PREFERENCE_EVAL &rarr; COUNT_SAME_POSITIONS    (P = 0.0163)
#
# PREFERENCE_EVAL &rarr; COUNT_ONCE_PER_EXTERNAL_OBJECTS    (P = 0.0379)
#
# PREFERENCE_EVAL &rarr; COUNT_MEASURE    (P = 0.0163)
#
# COUNT &rarr; (count PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# PREF_NAME_AND_TYPES &rarr; PREFERENCE_NAME [ PREF_OBJECT_TYPE ]*    (P = 1.0000)
#
# PREF_OBJECT_TYPE &rarr; : TYPE_NAME    (P = 1.0000)
#
# COUNT_OVERLAPPING &rarr; (count-overlapping PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_ONCE &rarr; (count-once PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_ONCE_PER_OBJECTS &rarr; (count-once-per-objects PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_LONGEST &rarr; (count-longest PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_SHORTEST &rarr; (count-shortest PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_TOTAL &rarr; (count-total PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_INCREASING_MEASURE &rarr; (count-increasing-measure PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_UNIQUE_POSITIONS &rarr; (count-unique-positions PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_SAME_POSITIONS &rarr; (count-same-positions PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_ONCE_PER_EXTERNAL_OBJECTS &rarr; (count-once-per-external-objects PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# COUNT_MEASURE &rarr; (count-measure PREF_NAME_AND_TYPES )    (P = 1.0000)
#
# SCORING_COMPARISON &rarr; SCORING_COMP    (P = 0.7917)
#
# SCORING_COMPARISON &rarr; SCORING_EQUALS_COMP    (P = 0.2083)
#
# SCORING_COMP &rarr; ( BINARY_COMP SCORING_EXPR SCORING_EXPR )    (P = 1.0000)
#
# SCORING_EQUALS_COMP &rarr; (= [ SCORING_EXPR ]+ )    (P = 1.0000)
#
# SCORING_DEF &rarr; (:scoring SCORING )    (P = 1.0000)
#
# SCORING &rarr; SCORING_EXPR    (P = 1.0000)
#
# ## Token rule expansions
#
# TYPE_NAME &rarr; hexagonal_bin    (P = 0.0440)
#
# TYPE_NAME &rarr; triangular_ramp    (P = 0.0056)
#
# TYPE_NAME &rarr; ball    (P = 0.0005)
#
# TYPE_NAME &rarr; building    (P = 0.0425)
#
# TYPE_NAME &rarr; block    (P = 0.0063)
#
# TYPE_NAME &rarr; dodgeball    (P = 0.1761)
#
# TYPE_NAME &rarr; curved_wooden_ramp    (P = 0.0056)
#
# TYPE_NAME &rarr; wall    (P = 0.0063)
#
# TYPE_NAME &rarr; teddy_bear    (P = 0.0112)
#
# TYPE_NAME &rarr; pillow    (P = 0.0015)
#
# TYPE_NAME &rarr; game_object    (P = 0.0112)
#
# TYPE_NAME &rarr; pyramid_block    (P = 0.0126)
#
# TYPE_NAME &rarr; cube_block    (P = 0.0126)
#
# TYPE_NAME &rarr; chair    (P = 0.0112)
#
# TYPE_NAME &rarr; bridge_block    (P = 0.0010)
#
# TYPE_NAME &rarr; flat_block    (P = 0.0112)
#
# TYPE_NAME &rarr; tall_cylindrical_block    (P = 0.0063)
#
# TYPE_NAME &rarr; doggie_bed    (P = 0.0252)
#
# TYPE_NAME &rarr; color    (P = 0.0127)
#
# TYPE_NAME &rarr; shelf    (P = 0.0212)
#
# TYPE_NAME &rarr; drawer    (P = 0.0005)
#
# TYPE_NAME &rarr; beachball    (P = 0.0943)
#
# TYPE_NAME &rarr; sliding_door    (P = 0.0042)
#
# TYPE_NAME &rarr; green_triangular_ramp    (P = 0.0021)
#
# TYPE_NAME &rarr; blinds    (P = 0.0005)
#
# TYPE_NAME &rarr; book    (P = 0.0189)
#
# TYPE_NAME &rarr; desk_shelf    (P = 0.0042)
#
# TYPE_NAME &rarr; rug    (P = 0.0063)
#
# TYPE_NAME &rarr; watch    (P = 0.0056)
#
# TYPE_NAME &rarr; yellow_pyramid_block    (P = 0.0063)
#
# TYPE_NAME &rarr; red_pyramid_block    (P = 0.0063)
#
# TYPE_NAME &rarr; blue_pyramid_block    (P = 0.0126)
#
# TYPE_NAME &rarr; golfball    (P = 0.0629)
#
# TYPE_NAME &rarr; cylindrical_block    (P = 0.0063)
#
# TYPE_NAME &rarr; desktop    (P = 0.0005)
#
# TYPE_NAME &rarr; red_dodgeball    (P = 0.0085)
#
# TYPE_NAME &rarr; blue_cube_block    (P = 0.0126)
#
# TYPE_NAME &rarr; yellow_cube_block    (P = 0.0126)
#
# TYPE_NAME &rarr; tan_cube_block    (P = 0.0021)
#
# TYPE_NAME &rarr; top_drawer    (P = 0.0063)
#
# TYPE_NAME &rarr; red    (P = 0.0440)
#
# TYPE_NAME &rarr; yellow    (P = 0.0629)
#
# TYPE_NAME &rarr; pink    (P = 0.0629)
#
# TYPE_NAME &rarr; laptop    (P = 0.0393)
#
# TYPE_NAME &rarr; cellphone    (P = 0.0337)
#
# TYPE_NAME &rarr; key_chain    (P = 0.0281)
#
# TYPE_NAME &rarr; main_light_switch    (P = 0.0005)
#
# TYPE_NAME &rarr; alarm_clock    (P = 0.0126)
#
# TYPE_NAME &rarr; mug    (P = 0.0169)
#
# TYPE_NAME &rarr; cd    (P = 0.0337)
#
# TYPE_NAME &rarr; bed    (P = 0.0063)
#
# TYPE_NAME &rarr; side_table    (P = 0.0063)
#
# TYPE_NAME &rarr; floor    (P = 0.0116)
#
# TYPE_NAME &rarr; basketball    (P = 0.0881)
#
# TYPE_NAME &rarr; lamp    (P = 0.0112)
#
# TYPE_NAME &rarr; credit_card    (P = 0.0056)
#
# TYPE_NAME &rarr; pencil    (P = 0.0112)
#
# TYPE_NAME &rarr; pen    (P = 0.0112)
#
# TYPE_NAME &rarr; triangle_block    (P = 0.0063)
#
# TYPE_NAME &rarr; agent    (P = 0.0538)
#
# TYPE_NAME &rarr; upright    (P = 0.0050)
#
# TYPE_NAME &rarr; door    (P = 0.0075)
#
# TYPE_NAME &rarr; desk    (P = 0.0322)
#
# TYPE_NAME &rarr; front    (P = 0.0050)
#
# TYPE_NAME &rarr; back    (P = 0.0025)
#
# TYPE_NAME &rarr; room_center    (P = 0.0171)
#
# TYPE_NAME &rarr; upside_down    (P = 0.0010)
#
# TYPE_NAME &rarr; left    (P = 0.0010)
#
# TYPE_NAME &rarr; right    (P = 0.0010)
#
# TYPE_NAME &rarr; west_wall    (P = 0.0010)
#
# TYPE_NAME &rarr; south_wall    (P = 0.0005)
#
# TYPE_NAME &rarr; pink_dodgeball    (P = 0.0377)
#
# TYPE_NAME &rarr; green_golfball    (P = 0.0020)
#
# TYPE_NAME &rarr; bottom_shelf    (P = 0.0005)
#
# TYPE_NAME &rarr; top_shelf    (P = 0.0025)
#
# TYPE_NAME &rarr; front_left_corner    (P = 0.0010)
#
# TYPE_NAME &rarr; blue    (P = 0.0063)
#
# TYPE_NAME &rarr; brown    (P = 0.0063)
#
# TYPE_NAME &rarr; green    (P = 0.0314)
#
# TYPE_NAME &rarr; tan    (P = 0.0063)
#
# TYPE_NAME &rarr; sideways    (P = 0.0015)
#
# TYPE_NAME &rarr; east_sliding_door    (P = 0.0005)
#
# TYPE_NAME &rarr; north_wall    (P = 0.0005)
#
# TYPE_NAME &rarr; south_west_corner    (P = 0.0010)
#
# TYPE_NAME &rarr; blue_dodgeball    (P = 0.0377)
#
# TYPE_NAME &rarr; orange    (P = 0.0189)
#
# TYPE_NAME &rarr; purple    (P = 0.0252)
#
# TYPE_NAME &rarr; white    (P = 0.0063)
#
# BINARY_COMP &rarr; <=    (P = 0.1538)
#
# BINARY_COMP &rarr; <    (P = 0.1538)
#
# BINARY_COMP &rarr; =    (P = 0.3590)
#
# BINARY_COMP &rarr; >=    (P = 0.2051)
#
# BINARY_COMP &rarr; >    (P = 0.1282)
#
# NUMBER &rarr; 0    (P = 0.0164)
#
# NUMBER &rarr; 1    (P = 0.0164)
#
# NUMBER &rarr; 2    (P = 0.0164)
#
# NUMBER &rarr; 3    (P = 0.0164)
#
# NUMBER &rarr; 4    (P = 0.0164)
#
# NUMBER &rarr; 5    (P = 0.0164)
#
# NUMBER &rarr; 6    (P = 0.0164)
#
# NUMBER &rarr; 7    (P = 0.0164)
#
# NUMBER &rarr; 8    (P = 0.0164)
#
# NUMBER &rarr; 9    (P = 0.0164)
#
# NUMBER &rarr; 10    (P = 0.0164)
#
# NUMBER &rarr; 1    (P = 0.0492)
#
# NUMBER &rarr; 0.5    (P = 0.0033)
#
# NUMBER &rarr; 2    (P = 0.1148)
#
# NUMBER &rarr; 6    (P = 0.0361)
#
# NUMBER &rarr; 3    (P = 0.1279)
#
# NUMBER &rarr; 4    (P = 0.0426)
#
# NUMBER &rarr; 10    (P = 0.0984)
#
# NUMBER &rarr; 20    (P = 0.0197)
#
# NUMBER &rarr; 30    (P = 0.0197)
#
# NUMBER &rarr; 5    (P = 0.1082)
#
# NUMBER &rarr; 8    (P = 0.0098)
#
# NUMBER &rarr; 300    (P = 0.0098)
#
# NUMBER &rarr; 15    (P = 0.0262)
#
# NUMBER &rarr; 40    (P = 0.0066)
#
# NUMBER &rarr; 180    (P = 0.0066)
#
# NUMBER &rarr; 50    (P = 0.0131)
#
# NUMBER &rarr; 12    (P = 0.0033)
#
# NUMBER &rarr; 7    (P = 0.0066)
#
# NUMBER &rarr; 100    (P = 0.0131)
#
# NUMBER &rarr; 25    (P = 0.0033)
#
# NUMBER &rarr; 16    (P = 0.0033)
#
# NUMBER &rarr; 0.7    (P = 0.0033)
#
# NUMBER &rarr; 18    (P = 0.0066)
#
# NUMBER &rarr; 60    (P = 0.0033)
#
# MULTI_OP &rarr; +    (P = 0.2903)
#
# MULTI_OP &rarr; *    (P = 0.7097)
#
# BINARY_OP &rarr; -    (P = 0.5000)
#
# BINARY_OP &rarr; /    (P = 0.5000)

# %%
sampler.rules['game_def']

# %%
game_texts = list(load_games_from_file('../dsl/interactive-beta.pddl'))

# %%
sampler.rules['predicate_or_function_term']['term']['token_posterior']
# Out:
# {'agent': 0.053822937625754526,
#  'upright': 0.005030181086519115,
#  'top_drawer': 0.002012072434607646,
#  'door': 0.007545271629778672,
#  'bed': 0.025150905432595575,
#  'desk': 0.03219315895372234,
#  'floor': 0.011569416498993963,
#  'front': 0.005030181086519115,
#  'back': 0.0025150905432595573,
#  'block': 0.0015090543259557343,
#  'room_center': 0.01710261569416499,
#  'rug': 0.01710261569416499,
#  'upside_down': 0.001006036217303823,
#  'left': 0.001006036217303823,
#  'right': 0.001006036217303823,
#  'main_light_switch': 0.0005030181086519115,
#  'desktop': 0.0005030181086519115,
#  'west_wall': 0.001006036217303823,
#  'south_wall': 0.0005030181086519115,
#  'pillow': 0.0015090543259557343,
#  'side_table': 0.002012072434607646,
#  'bridge_block': 0.001006036217303823,
#  'pink_dodgeball': 0.006036217303822937,
#  'ball': 0.0005030181086519115,
#  'drawer': 0.0005030181086519115,
#  'blinds': 0.0005030181086519115,
#  'green_golfball': 0.002012072434607646,
#  'bottom_shelf': 0.0005030181086519115,
#  'top_shelf': 0.0025150905432595573,
#  'yellow': 0.001006036217303823,
#  'front_left_corner': 0.001006036217303823,
#  'pink': 0.004024144869215292,
#  'blue': 0.0025150905432595573,
#  'brown': 0.002012072434607646,
#  'green': 0.001006036217303823,
#  'tan': 0.0005030181086519115,
#  'sideways': 0.0015090543259557343,
#  'east_sliding_door': 0.0005030181086519115,
#  'north_wall': 0.0005030181086519115,
#  'south_west_corner': 0.001006036217303823,
#  'variable': 0.7811871227364185}
